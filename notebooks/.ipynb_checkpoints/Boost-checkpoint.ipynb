# %%
#from sklearn.experimental import enable_iterative_imputer
#from sklearn.preprocessing import FunctionTransformer
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer #, IterativeImputer
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder, StandardScaler, MaxAbsScaler

from sklearn.metrics import precision_score, recall_score, accuracy_score, classification_report, ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score, roc_curve, auc, SCORERS
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from xgboost import XGBClassifier

from sklearn import set_config
set_config(display ="diagram")

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full_df=pd.read_csv('../data/processed/crashes.gz', compression='gzip', low_memory=False)

# %%
selected_df=full_df[['GUILTY','DEVICE_CONDITION', 'FIRST_CRASH_TYPE', 'FIRST_CONTACT_POINT', 
           'TRAFFICWAY_TYPE','ROADWAY_SURFACE_COND','VEHICLE_DEFECT',
             'DRIVERS_LICENSE_CLASS', 'AGE_GROUP', 'VEHICLE_AGE', 'AIRBAG_DEPLOYED',
            'PHYSICAL_CONDITION', 'MANEUVER',  'DRIVER_VISION',  'ALIGNMENT' ,  'TRAFFIC_CONTROL_DEVICE',
                    'NUM_PASSENGERS','SUN_GLARE','VEHICLE_YEAR','AGE']]

#SAFETY_EQUIPMENT

explore_cat_vars(full_df, 42)
# Out:
# --------------------------------------
# PERSON_TYPE
# --------------------------------------
# DRIVER    304719
# Name: PERSON_TYPE, dtype: int64
# --------------------------------------
# SEAT_NO
# --------------------------------------
# Series([], Name: SEAT_NO, dtype: int64)
# --------------------------------------
# SEX
# --------------------------------------
# M    175916
# F    128803
# Name: SEX, dtype: int64
# --------------------------------------
# DRIVERS_LICENSE_CLASS
# --------------------------------------
# D     275052
# B       8011
# C       7762
# A       6800
# DM      5000
# AM       810
# BM       685
# CD       599
# Name: DRIVERS_LICENSE_CLASS, dtype: int64
# --------------------------------------
# SAFETY_EQUIPMENT
# --------------------------------------
# SAFETY BELT USED                   255692
# USAGE UNKNOWN                       39990
# NONE PRESENT                         7394
# SAFETY BELT NOT USED                 1623
# SHOULD/LAP BELT USED IMPROPERLY        20
# Name: SAFETY_EQUIPMENT, dtype: int64
# --------------------------------------
# AIRBAG_DEPLOYED
# --------------------------------------
# DID NOT DEPLOY                            232056
# NOT APPLICABLE                             52819
# DEPLOYED, FRONT                            10869
# DEPLOYED, COMBINATION                       5766
# DEPLOYED, SIDE                              3068
# DEPLOYED OTHER (KNEE, AIR, BELT, ETC.)       141
# Name: AIRBAG_DEPLOYED, dtype: int64
# --------------------------------------
# EJECTION
# --------------------------------------
# NONE                  303374
# TOTALLY EJECTED          605
# UNKNOWN                  415
# PARTIALLY EJECTED        217
# TRAPPED/EXTRICATED       108
# Name: EJECTION, dtype: int64
# --------------------------------------
# INJURY_CLASSIFICATION
# --------------------------------------
# NO INDICATION OF INJURY     283823
# NONINCAPACITATING INJURY     10783
# REPORTED, NOT EVIDENT         8516
# INCAPACITATING INJURY         1574
# FATAL                           23
# Name: INJURY_CLASSIFICATION, dtype: int64
# --------------------------------------
# EMS_RUN_NO
# --------------------------------------
# Series([], Name: EMS_RUN_NO, dtype: int64)
# --------------------------------------
# DRIVER_ACTION
# --------------------------------------
# NONE                                 191106
# FAILED TO YIELD                       30979
# FOLLOWED TOO CLOSELY                  19666
# OTHER                                 18816
# IMPROPER TURN                          7575
# IMPROPER LANE CHANGE                   7217
# IMPROPER BACKING                       6874
# UNKNOWN                                6696
# IMPROPER PASSING                       4507
# TOO FAST FOR CONDITIONS                4414
# DISREGARDED CONTROL DEVICES            3851
# IMPROPER PARKING                        908
# WRONG WAY/SIDE                          646
# CELL PHONE USE OTHER THAN TEXTING       436
# OVERCORRECTED                           399
# EMERGENCY VEHICLE ON CALL               297
# EVADING POLICE VEHICLE                  161
# TEXTING                                 110
# STOPPED SCHOOL BUS                       50
# LICENSE RESTRICTIONS                     11
# Name: DRIVER_ACTION, dtype: int64
# --------------------------------------
# DRIVER_VISION
# --------------------------------------
# NOT OBSCURED              293444
# OTHER                       3342
# MOVING VEHICLES             3194
# PARKED VEHICLES             1902
# WINDSHIELD (WATER/ICE)      1611
# BLINDED - SUNLIGHT           668
# TREES, PLANTS                210
# BUILDINGS                    195
# HILLCREST                     42
# BLINDED - HEADLIGHTS          40
# EMBANKMENT                    35
# BLOWING MATERIALS             23
# SIGNBOARD                     13
# Name: DRIVER_VISION, dtype: int64
# --------------------------------------
# PHYSICAL_CONDITION
# --------------------------------------
# NORMAL                          300404
# IMPAIRED - ALCOHOL                1290
# FATIGUED/ASLEEP                    991
# OTHER                              496
# EMOTIONAL                          481
# ILLNESS/FAINTED                    356
# REMOVED BY EMS                     343
# HAD BEEN DRINKING                  152
# IMPAIRED - DRUGS                   127
# MEDICATED                           45
# IMPAIRED - ALCOHOL AND DRUGS        34
# Name: PHYSICAL_CONDITION, dtype: int64
# --------------------------------------
# PEDPEDAL_ACTION
# --------------------------------------
# Series([], Name: PEDPEDAL_ACTION, dtype: int64)
# --------------------------------------
# PEDPEDAL_VISIBILITY
# --------------------------------------
# Series([], Name: PEDPEDAL_VISIBILITY, dtype: int64)
# --------------------------------------
# PEDPEDAL_LOCATION
# --------------------------------------
# Series([], Name: PEDPEDAL_LOCATION, dtype: int64)
# --------------------------------------
# BAC_RESULT
# --------------------------------------
# TEST NOT OFFERED                   299389
# TEST REFUSED                         4044
# TEST PERFORMED, RESULTS UNKNOWN       738
# TEST TAKEN                            548
# Name: BAC_RESULT, dtype: int64
# --------------------------------------
# BAC_RESULT VALUE
# --------------------------------------
# 0.00    39
# 0.18    39
# 0.14    34
# 0.20    31
# 0.17    30
# 0.21    26
# 0.16    24
# 0.15    21
# 0.23    21
# 0.19    18
# 0.22    17
# 0.13    15
# 0.24    15
# 0.12    14
# 0.11    13
# 0.26    11
# 0.09    10
# 0.04     9
# 0.29     8
# 0.10     8
# 0.25     8
# 0.30     7
# 0.27     7
# 0.08     5
# 0.06     4
# 0.05     4
# 0.07     3
# 0.02     3
# 0.28     3
# 0.03     3
# 0.32     2
# 0.35     2
# 0.36     1
# 0.34     1
# 0.95     1
# 0.31     1
# 0.33     1
# 0.67     1
# 0.88     1
# Name: BAC_RESULT VALUE, dtype: int64
# --------------------------------------
# CELL_PHONE_USE
# --------------------------------------
# Y    232
# N    141
# Name: CELL_PHONE_USE, dtype: int64
# --------------------------------------
# AGE_GROUP
# --------------------------------------
# ADULTS          112383
# YOUNG ADULTS     88619
# MIDDLE AGED      47903
# YOUNG            44009
# SENIORS           9354
# 80+               2451
# Name: AGE_GROUP, dtype: int64
# --------------------------------------
# UNIT_NO
# --------------------------------------
# 2    183641
# 1    111602
# 3      8259
# 4      1009
# 5       152
# 6        36
# 7        12
# 8         5
# 9         2
# 0         1
# Name: UNIT_NO, dtype: int64
# --------------------------------------
# UNIT_TYPE
# --------------------------------------
# DRIVER    304719
# Name: UNIT_TYPE, dtype: int64
# --------------------------------------
# NUM_PASSENGERS
# --------------------------------------
# 1.0     43814
# 2.0     11778
# 3.0      4398
# 4.0      1563
# 5.0       418
# 6.0       151
# 7.0        59
# 8.0        38
# 10.0       24
# 9.0        19
# 11.0       17
# 14.0       10
# 12.0       10
# 15.0        9
# 19.0        6
# 18.0        5
# 25.0        3
# 13.0        3
# 38.0        2
# 17.0        2
# 35.0        2
# 29.0        2
# 23.0        2
# 24.0        2
# 36.0        1
# 37.0        1
# 20.0        1
# 40.0        1
# 26.0        1
# 42.0        1
# 43.0        1
# 32.0        1
# 59.0        1
# 34.0        1
# 27.0        1
# 28.0        1
# 16.0        1
# Name: NUM_PASSENGERS, dtype: int64
# --------------------------------------
# CMRC_VEH_I
# --------------------------------------
# Y    2306
# N    1722
# Name: CMRC_VEH_I, dtype: int64
# --------------------------------------
# VEHICLE_DEFECT
# --------------------------------------
# NONE                301486
# BRAKES                1769
# OTHER                  593
# STEERING               260
# TIRES                  242
# WHEELS                 134
# SUSPENSION             105
# ENGINE/MOTOR            62
# LIGHTS                  25
# WINDOWS                 13
# FUEL SYSTEM             11
# RESTRAINT SYSTEM         6
# EXHAUST                  6
# SIGNALS                  4
# CARGO                    2
# TRAILER COUPLING         1
# Name: VEHICLE_DEFECT, dtype: int64
# --------------------------------------
# VEHICLE_TYPE
# --------------------------------------
# PASSENGER                      221504
# SPORT UTILITY VEHICLE (SUV)     46535
# VAN/MINI-VAN                    16354
# PICKUP                           9330
# TRUCK - SINGLE UNIT              6272
# BUS OVER 15 PASS.                4724
# Name: VEHICLE_TYPE, dtype: int64
# --------------------------------------
# VEHICLE_USE
# --------------------------------------
# PERSONAL                    266772
# OTHER                         8246
# TAXI/FOR HIRE                 7437
# RIDESHARE SERVICE             3994
# COMMERCIAL - SINGLE UNIT      3509
# CTA                           2918
# POLICE                        2270
# UNKNOWN/NA                    2167
# NOT IN USE                    1602
# CONSTRUCTION/MAINTENANCE      1457
# OTHER TRANSIT                 1392
# SCHOOL BUS                    1018
# COMMERCIAL - MULTI-UNIT        352
# MASS TRANSIT                   299
# TOW TRUCK                      283
# STATE OWNED                    281
# DRIVER EDUCATION               275
# AMBULANCE                      173
# FIRE                           121
# LAWN CARE/LANDSCAPING          109
# AGRICULTURE                     20
# CAMPER/RV - SINGLE UNIT         12
# MILITARY                        10
# HOUSE TRAILER                    2
# Name: VEHICLE_USE, dtype: int64
# --------------------------------------
# TRAVEL_DIRECTION
# --------------------------------------
# N          75586
# S          73306
# W          68905
# E          66865
# SE          4719
# UNKNOWN     4136
# NW          4096
# NE          3562
# SW          3544
# Name: TRAVEL_DIRECTION, dtype: int64
# --------------------------------------
# MANEUVER
# --------------------------------------
# STRAIGHT AHEAD                        179270
# SLOW/STOP IN TRAFFIC                   44749
# TURNING LEFT                           22383
# TURNING RIGHT                          11273
# BACKING                                 9957
# CHANGING LANES                          6092
# PASSING/OVERTAKING                      5566
# OTHER                                   4647
# ENTERING TRAFFIC LANE FROM PARKING      3852
# STARTING IN TRAFFIC                     2723
# MERGING                                 2012
# AVOIDING VEHICLES/OBJECTS               1701
# U-TURN                                  1663
# SKIDDING/CONTROL LOSS                   1631
# LEAVING TRAFFIC LANE TO PARK            1631
# ENTER FROM DRIVE/ALLEY                  1559
# SLOW/STOP - LEFT TURN                   1444
# SLOW/STOP - RIGHT TURN                   902
# SLOW/STOP - LOAD/UNLOAD                  755
# NEGOTIATING A CURVE                      494
# DRIVING WRONG WAY                        257
# TURNING ON RED                           117
# DIVERGING                                 37
# PARKED                                     4
# Name: MANEUVER, dtype: int64
# --------------------------------------
# TOWED_I
# --------------------------------------
# Y    41019
# N     1996
# Name: TOWED_I, dtype: int64
# --------------------------------------
# FIRE_I
# --------------------------------------
# N    88
# Y    69
# Name: FIRE_I, dtype: int64
# --------------------------------------
# OCCUPANT_CNT
# --------------------------------------
# 1.0     242413
# 2.0      43798
# 3.0      11769
# 4.0       4394
# 5.0       1563
# 6.0        413
# 7.0        150
# 8.0         59
# 9.0         36
# 11.0        22
# 10.0        18
# 12.0        16
# 13.0        10
# 15.0         9
# 16.0         8
# 20.0         6
# 19.0         5
# 26.0         3
# 14.0         3
# 18.0         2
# 36.0         2
# 30.0         2
# 25.0         2
# 39.0         2
# 37.0         1
# 44.0         1
# 38.0         1
# 21.0         1
# 41.0         1
# 27.0         1
# 43.0         1
# 33.0         1
# 60.0         1
# 35.0         1
# 24.0         1
# 28.0         1
# 29.0         1
# 17.0         1
# Name: OCCUPANT_CNT, dtype: int64
# --------------------------------------
# EXCEED_SPEED_LIMIT_I
# --------------------------------------
# Y    248
# N    114
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
# --------------------------------------
# AREA_00_I
# --------------------------------------
# Y    11058
# N     1576
# Name: AREA_00_I, dtype: int64
# --------------------------------------
# AREA_01_I
# --------------------------------------
# Y    84845
# N     3018
# Name: AREA_01_I, dtype: int64
# --------------------------------------
# AREA_02_I
# --------------------------------------
# Y    58763
# N     2216
# Name: AREA_02_I, dtype: int64
# --------------------------------------
# AREA_03_I
# --------------------------------------
# Y    33927
# N     1196
# Name: AREA_03_I, dtype: int64
# --------------------------------------
# AREA_04_I
# --------------------------------------
# Y    36731
# N     1353
# Name: AREA_04_I, dtype: int64
# --------------------------------------
# AREA_05_I
# --------------------------------------
# Y    61303
# N     1538
# Name: AREA_05_I, dtype: int64
# --------------------------------------
# AREA_06_I
# --------------------------------------
# Y    54416
# N     1690
# Name: AREA_06_I, dtype: int64
# --------------------------------------
# AREA_07_I
# --------------------------------------
# Y    40264
# N     1619
# Name: AREA_07_I, dtype: int64
# --------------------------------------
# AREA_08_I
# --------------------------------------
# Y    51381
# N     2488
# Name: AREA_08_I, dtype: int64
# --------------------------------------
# AREA_09_I
# --------------------------------------
# Y    12105
# N      597
# Name: AREA_09_I, dtype: int64
# --------------------------------------
# AREA_10_I
# --------------------------------------
# Y    19536
# N      936
# Name: AREA_10_I, dtype: int64
# --------------------------------------
# AREA_11_I
# --------------------------------------
# Y    39918
# N     2093
# Name: AREA_11_I, dtype: int64
# --------------------------------------
# AREA_12_I
# --------------------------------------
# Y    39635
# N     1256
# Name: AREA_12_I, dtype: int64
# --------------------------------------
# AREA_99_I
# --------------------------------------
# Y    2520
# N     491
# Name: AREA_99_I, dtype: int64
# --------------------------------------
# FIRST_CONTACT_POINT
# --------------------------------------
# FRONT                50330
# REAR                 42296
# REAR-LEFT            38952
# FRONT-LEFT           29207
# FRONT-RIGHT          28042
# OTHER                26531
# SIDE-RIGHT           23702
# SIDE-LEFT            18093
# TOTAL (ALL AREAS)    17837
# REAR-RIGHT           14968
# ROOF                  8895
# UNDER CARRIAGE        3248
# NONE                  2618
# Name: FIRST_CONTACT_POINT, dtype: int64
# --------------------------------------
# COMMERCIAL_SRC
# --------------------------------------
# DRIVER           641
# SIDE OF TRUCK    493
# PAPERS           163
# LOG BOOK          51
# Name: COMMERCIAL_SRC, dtype: int64
# --------------------------------------
# CARRIER_STATE
# --------------------------------------
# IL    1530
# IN      67
# PA      31
# AZ      18
# TX      18
# OH      17
# WI      16
# FL      13
# IA      12
# MN      11
# GA      11
# CA      10
# NJ       7
# OK       6
# TN       5
# KS       5
# MI       4
# NC       3
# NB       3
# VA       3
# CT       3
# MO       3
# NY       2
# ND       2
# MA       2
# WA       2
# MS       2
# AR       2
# SD       1
# MD       1
# KY       1
# UT       1
# XX       1
# ID       1
# Name: CARRIER_STATE, dtype: int64
# --------------------------------------
# HAZMAT_PLACARDS_I
# --------------------------------------
# N    14
# Y     9
# Name: HAZMAT_PLACARDS_I, dtype: int64
# --------------------------------------
# HAZMAT_NAME
# --------------------------------------
# PROPANE           1
# GAS AND DIESEL    1
# CORROSIVE         1
# PETROLEUM         1
# MEDICAL WASTE     1
# Name: HAZMAT_NAME, dtype: int64
# --------------------------------------
# UN_NO
# --------------------------------------
# UNK     11
# DNA      2
# 1593     2
# 7896     1
# 2063     1
# 6736     1
# 3925     1
# 0000     1
# 4194     1
# 5606     1
# 1772     1
# 5727     1
# 1909     1
# 1933     1
# 1908     1
# B295     1
# 1195     1
# 8086     1
# 2002     1
# 6423     1
# 2187     1
# 1151     1
# 1450     1
# 2RTT     1
# 1075     1
# 0064     1
# 9103     1
# 1122     1
# 1993     1
# 1857     1
# 2157     1
# 8127     1
# 3811     1
# 4984     1
# 2654     1
# 1680     1
# 226A     1
# Name: UN_NO, dtype: int64
# --------------------------------------
# HAZMAT_PRESENT_I
# --------------------------------------
# N    1339
# U      34
# Y       3
# Name: HAZMAT_PRESENT_I, dtype: int64
# --------------------------------------
# HAZMAT_REPORT_I
# --------------------------------------
# N    1224
# U     103
# Name: HAZMAT_REPORT_I, dtype: int64
# --------------------------------------
# HAZMAT_REPORT_NO
# --------------------------------------
# Series([], Name: HAZMAT_REPORT_NO, dtype: int64)
# --------------------------------------
# MCS_REPORT_I
# --------------------------------------
# N    1155
# U     191
# Y       2
# Name: MCS_REPORT_I, dtype: int64
# --------------------------------------
# MCS_REPORT_NO
# --------------------------------------
# Series([], Name: MCS_REPORT_NO, dtype: int64)
# --------------------------------------
# HAZMAT_VIO_CAUSE_CRASH_I
# --------------------------------------
# N    1311
# U      39
# Name: HAZMAT_VIO_CAUSE_CRASH_I, dtype: int64
# --------------------------------------
# MCS_VIO_CAUSE_CRASH_I
# --------------------------------------
# N    1238
# U      95
# Y       3
# Name: MCS_VIO_CAUSE_CRASH_I, dtype: int64
# --------------------------------------
# IDOT_PERMIT_NO
# --------------------------------------
# UNKNOWN      11
# UNK           6
# DNA           4
# 1762064       2
# 331469        1
# 478701        1
# 653010        1
# 2066538       1
# 104000096     1
# 608224        1
# 76764         1
# 690498        1
# 2435295       1
# 2461132       1
# 82250         1
# 14864876      1
# 1742100       1
# 11516         1
# 1913          1
# 798100        1
# 282577        1
# 2817633       1
# NOT AVAIL     1
# 0533220       1
# 3388947       1
# 899748        1
# 99            1
# 704116        1
# 1551492       1
# 1678014       1
# CLS216145     1
# 1959522       1
# MC186654      1
# 3070267       1
# 175882        1
# 781086        1
# 1751855       1
# 540837        1
# 704220        1
# DT3710        1
# 948584        1
# Name: IDOT_PERMIT_NO, dtype: int64
# --------------------------------------
# WIDE_LOAD_I
# --------------------------------------
# N    4
# Y    4
# Name: WIDE_LOAD_I, dtype: int64
# --------------------------------------
# TRAILER1_WIDTH
# --------------------------------------
# 0-96      125
# >102       29
# 97-102     21
# Name: TRAILER1_WIDTH, dtype: int64
# --------------------------------------
# TRAILER2_WIDTH
# --------------------------------------
# 0-96      17
# >102       9
# 97-102     2
# Name: TRAILER2_WIDTH, dtype: int64
# --------------------------------------
# TRAILER1_LENGTH
# --------------------------------------
# 30.0     11
# 15.0      8
# 53.0      8
# 20.0      8
# 16.0      6
# 24.0      5
# 25.0      5
# 40.0      4
# 26.0      4
# 35.0      4
# 28.0      4
# 60.0      2
# 6.0       2
# 18.0      2
# 21.0      1
# 1.0       1
# 22.0      1
# 96.0      1
# 14.0      1
# 65.0      1
# 32.0      1
# 51.0      1
# 12.0      1
# 115.0     1
# 50.0      1
# 3.0       1
# 54.0      1
# Name: TRAILER1_LENGTH, dtype: int64
# --------------------------------------
# TRAILER2_LENGTH
# --------------------------------------
# 30.0    1
# Name: TRAILER2_LENGTH, dtype: int64
# --------------------------------------
# AXLE_CNT
# --------------------------------------
# 2.0    411
# 3.0    138
# 4.0     14
# 5.0     11
# 1.0      8
# 6.0      8
# Name: AXLE_CNT, dtype: int64
# --------------------------------------
# VEHICLE_CONFIG
# --------------------------------------
# SINGLE UNIT TRUCK, 2 AXLES, 6 TIRES    652
# BUS                                    630
# SINGLE UNIT TRUCK, 3 OR MORE AXLES      96
# UNKNOWN HEAVY TRUCK                     93
# TRUCK/TRACTOR                           67
# TRUCK/TRAILER                           43
# TRACTOR/SEMI-TRAILER                    41
# Name: VEHICLE_CONFIG, dtype: int64
# --------------------------------------
# CARGO_BODY_TYPE
# --------------------------------------
# BUS                 614
# VAN/ENCLOSED BOX    518
# OTHER               281
# GARBAGE/REFUSE       72
# FLATBED              54
# DUMP                 45
# CONCRETE MIXER       19
# TANK                 11
# AUTO TRANSPORTER      6
# Name: CARGO_BODY_TYPE, dtype: int64
# --------------------------------------
# LOAD_TYPE
# --------------------------------------
# OTHER                     1118
# UNKNOWN                    247
# CONSTRUCTION EQUIPMENT      49
# BUILDING MATERIALS          35
# STEEL COILS                  5
# FARM EQUIPMENT               2
# Name: LOAD_TYPE, dtype: int64
# --------------------------------------
# HAZMAT_OUT_OF_SERVICE_I
# --------------------------------------
# N    1300
# Y       3
# Name: HAZMAT_OUT_OF_SERVICE_I, dtype: int64
# --------------------------------------
# MCS_OUT_OF_SERVICE_I
# --------------------------------------
# N    1339
# Y       6
# Name: MCS_OUT_OF_SERVICE_I, dtype: int64
# --------------------------------------
# HAZMAT_CLASS
# --------------------------------------
# MISCELLANEOUS                                                        91
# FLAMMABLE OR COMBUSTIBLE LIQUID                                       4
# GASES                                                                 3
# EXPLOSIVES                                                            2
# FLAMMABLE SOLID, SPONTANEOUSLY COMBUSTIBLE, OR DANGEROUS WHEN WET     1
# POISON (TOXIC) OR POISON INHALATION HAZARD                            1
# Name: HAZMAT_CLASS, dtype: int64
# --------------------------------------
# VEHICLE_AGE
# --------------------------------------
# 3-8 years old      109429
# 8-15 years old     106266
# 15-25 years old     68270
# 0-3 years old       16761
# 25+ years old        3993
# Name: VEHICLE_AGE, dtype: int64
# --------------------------------------
# CRASH_DATE_EST_I
# --------------------------------------
# Y    10609
# N     1553
# Name: CRASH_DATE_EST_I, dtype: int64
# --------------------------------------
# POSTED_SPEED_LIMIT
# --------------------------------------
# 30    234924
# 35     23112
# 25     16472
# 20      7819
# 15      6701
# 40      4457
# 10      3513
# 0       3496
# 45      2446
# 5       1229
# 55       255
# 3         77
# 50        77
# 39        37
# 9         26
# 32        10
# 34         8
# 60         8
# 1          7
# 2          7
# 24         7
# 65         4
# 99         4
# 33         3
# 7          3
# 11         3
# 22         2
# 26         2
# 63         2
# 12         2
# 4          1
# 36         1
# 14         1
# 70         1
# 31         1
# 18         1
# Name: POSTED_SPEED_LIMIT, dtype: int64
# --------------------------------------
# TRAFFIC_CONTROL_DEVICE
# --------------------------------------
# NO CONTROLS                 150642
# TRAFFIC SIGNAL              112394
# STOP SIGN/FLASHER            37594
# OTHER                         1324
# LANE USE MARKING               844
# YIELD                          468
# OTHER REG. SIGN                290
# OTHER WARNING SIGN             272
# RAILROAD CROSSING GATE         247
# PEDESTRIAN CROSSING SIGN       139
# POLICE/FLAGMAN                 120
# DELINEATORS                    111
# SCHOOL ZONE                     88
# OTHER RAILROAD CROSSING         83
# FLASHING CONTROL SIGNAL         59
# RR CROSSING SIGN                24
# NO PASSING                      13
# BICYCLE CROSSING SIGN            7
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64
# --------------------------------------
# DEVICE_CONDITION
# --------------------------------------
# NO CONTROLS                 155878
# FUNCTIONING PROPERLY        143710
# FUNCTIONING IMPROPERLY        2059
# OTHER                         1715
# NOT FUNCTIONING               1124
# WORN REFLECTIVE MATERIAL       180
# MISSING                         53
# Name: DEVICE_CONDITION, dtype: int64
# --------------------------------------
# WEATHER_CONDITION
# --------------------------------------
# CLEAR                     251026
# RAIN                       29633
# SNOW                       11426
# CLOUDY/OVERCAST            10386
# OTHER                        724
# FOG/SMOKE/HAZE               484
# SLEET/HAIL                   462
# FREEZING RAIN/DRIZZLE        423
# BLOWING SNOW                 101
# SEVERE CROSS WIND GATE        54
# Name: WEATHER_CONDITION, dtype: int64
# --------------------------------------
# LIGHTING_CONDITION
# --------------------------------------
# DAYLIGHT                  219987
# DARKNESS, LIGHTED ROAD     60378
# DARKNESS                   10710
# DUSK                        8763
# DAWN                        4881
# Name: LIGHTING_CONDITION, dtype: int64
# --------------------------------------
# FIRST_CRASH_TYPE
# --------------------------------------
# REAR END                        102910
# SIDESWIPE SAME DIRECTION         59569
# TURNING                          59078
# ANGLE                            44493
# PARKED MOTOR VEHICLE             13022
# FIXED OBJECT                      5438
# SIDESWIPE OPPOSITE DIRECTION      5272
# HEAD ON                           3297
# PEDESTRIAN                        2922
# REAR TO FRONT                     2331
# PEDALCYCLIST                      2243
# OTHER OBJECT                      1466
# REAR TO SIDE                      1431
# OTHER NONCOLLISION                 580
# REAR TO REAR                       480
# ANIMAL                             140
# OVERTURNED                          37
# TRAIN                               10
# Name: FIRST_CRASH_TYPE, dtype: int64
# --------------------------------------
# TRAFFICWAY_TYPE
# --------------------------------------
# NOT DIVIDED                        141296
# DIVIDED - W/MEDIAN (NOT RAISED)     67185
# ONE-WAY                             26741
# DIVIDED - W/MEDIAN BARRIER          23010
# FOUR WAY                            14425
# PARKING LOT                         12302
# OTHER                                7303
# CENTER TURN LANE                     3219
# ALLEY                                2989
# T-INTERSECTION                       2895
# RAMP                                  991
# DRIVEWAY                              714
# UNKNOWN INTERSECTION TYPE             485
# Y-INTERSECTION                        362
# FIVE POINT, OR MORE                   301
# TRAFFIC ROUTE                         269
# NOT REPORTED                          140
# ROUNDABOUT                             52
# L-INTERSECTION                         40
# Name: TRAFFICWAY_TYPE, dtype: int64
# --------------------------------------
# LANE_CNT
# --------------------------------------
# 2.0         57349
# 4.0         38871
# 1.0         11715
# 3.0          6659
# 0.0          5236
# 6.0          3837
# 8.0          1718
# 5.0          1662
# 7.0           171
# 10.0          113
# 9.0            64
# 11.0           15
# 99.0           13
# 12.0           10
# 20.0            7
# 30.0            4
# 22.0            3
# 21.0            3
# 14.0            3
# 433634.0        2
# 44.0            2
# 40.0            1
# 28.0            1
# 15.0            1
# 41.0            1
# 218474.0        1
# Name: LANE_CNT, dtype: int64
# --------------------------------------
# ALIGNMENT
# --------------------------------------
# STRAIGHT AND LEVEL       296160
# STRAIGHT ON GRADE          4423
# CURVE, LEVEL               2430
# STRAIGHT ON HILLCREST      1077
# CURVE ON GRADE              502
# CURVE ON HILLCREST          127
# Name: ALIGNMENT, dtype: int64
# --------------------------------------
# ROADWAY_SURFACE_COND
# --------------------------------------
# DRY                243834
# WET                 46392
# SNOW OR SLUSH       11137
# ICE                  2757
# OTHER                 527
# SAND, MUD, DIRT        72
# Name: ROADWAY_SURFACE_COND, dtype: int64
# --------------------------------------
# ROAD_DEFECT
# --------------------------------------
# NO DEFECTS           298604
# RUT, HOLES             2459
# OTHER                  1613
# WORN SURFACE           1051
# SHOULDER DEFECT         747
# DEBRIS ON ROADWAY       245
# Name: ROAD_DEFECT, dtype: int64
# --------------------------------------
# REPORT_TYPE
# --------------------------------------
# NOT ON SCENE (DESK REPORT)    166449
# ON SCENE                      129060
# AMENDED                          162
# Name: REPORT_TYPE, dtype: int64
# --------------------------------------
# CRASH_TYPE
# --------------------------------------
# NO INJURY / DRIVE AWAY              221546
# INJURY AND / OR TOW DUE TO CRASH     83173
# Name: CRASH_TYPE, dtype: int64
# --------------------------------------
# INTERSECTION_RELATED_I
# --------------------------------------
# Y    89062
# N     3570
# Name: INTERSECTION_RELATED_I, dtype: int64
# --------------------------------------
# NOT_RIGHT_OF_WAY_I
# --------------------------------------
# Y    7528
# N     727
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
# --------------------------------------
# HIT_AND_RUN_I
# --------------------------------------
# Y    42194
# N     2722
# Name: HIT_AND_RUN_I, dtype: int64
# --------------------------------------
# DAMAGE
# --------------------------------------
# OVER $1,500      189092
# $501 - $1,500     84667
# $500 OR LESS      30960
# Name: DAMAGE, dtype: int64
# --------------------------------------
# PRIM_CONTRIBUTORY_CAUSE
# --------------------------------------
# UNABLE TO DETERMINE                                                                 58360
# FAILING TO YIELD RIGHT-OF-WAY                                                       52904
# FOLLOWING TOO CLOSELY                                                               52319
# IMPROPER OVERTAKING/PASSING                                                         18508
# FAILING TO REDUCE SPEED TO AVOID CRASH                                              18304
# IMPROPER LANE USAGE                                                                 15729
# IMPROPER TURNING/NO SIGNAL                                                          14552
# IMPROPER BACKING                                                                    12568
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  9139
# DISREGARDING TRAFFIC SIGNALS                                                         8401
# WEATHER                                                                              6795
# NOT APPLICABLE                                                                       6092
# DISREGARDING STOP SIGN                                                               4639
# DISTRACTION - FROM INSIDE VEHICLE                                                    3385
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     2976
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                 2889
# EQUIPMENT - VEHICLE CONDITION                                                        2590
# PHYSICAL CONDITION OF DRIVER                                                         1926
# DISTRACTION - FROM OUTSIDE VEHICLE                                                   1821
# DRIVING ON WRONG SIDE/WRONG WAY                                                      1577
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                   1424
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                  1287
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      986
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              819
# ROAD CONSTRUCTION/MAINTENANCE                                                         800
# DISREGARDING OTHER TRAFFIC SIGNS                                                      730
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     694
# CELL PHONE USE OTHER THAN TEXTING                                                     573
# DISREGARDING ROAD MARKINGS                                                            493
# TURNING RIGHT ON RED                                                                  294
# ANIMAL                                                                                246
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)           206
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       202
# TEXTING                                                                               152
# DISREGARDING YIELD SIGN                                                               118
# RELATED TO BUS STOP                                                                   118
# PASSING STOPPED SCHOOL BUS                                                             39
# OBSTRUCTED CROSSWALKS                                                                  33
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 24
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               7
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64
# --------------------------------------
# SEC_CONTRIBUTORY_CAUSE
# --------------------------------------
# NOT APPLICABLE                                                                      115563
# UNABLE TO DETERMINE                                                                  87759
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               18314
# FAILING TO YIELD RIGHT-OF-WAY                                                        14421
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  13669
# FOLLOWING TOO CLOSELY                                                                12664
# IMPROPER LANE USAGE                                                                   5995
# WEATHER                                                                               5509
# IMPROPER OVERTAKING/PASSING                                                           5501
# IMPROPER TURNING/NO SIGNAL                                                            4565
# IMPROPER BACKING                                                                      2459
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER      2219
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  1810
# DISREGARDING TRAFFIC SIGNALS                                                          1749
# DISTRACTION - FROM INSIDE VEHICLE                                                     1663
# DISREGARDING STOP SIGN                                                                1242
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   1136
# PHYSICAL CONDITION OF DRIVER                                                          1077
# EQUIPMENT - VEHICLE CONDITION                                                          973
# EXCEEDING AUTHORIZED SPEED LIMIT                                                       885
# DISTRACTION - FROM OUTSIDE VEHICLE                                                     791
# DRIVING ON WRONG SIDE/WRONG WAY                                                        632
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                     567
# ROAD CONSTRUCTION/MAINTENANCE                                                          461
# DISREGARDING ROAD MARKINGS                                                             424
# DISREGARDING OTHER TRAFFIC SIGNS                                                       394
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                               379
# CELL PHONE USE OTHER THAN TEXTING                                                      361
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                        356
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                      218
# TURNING RIGHT ON RED                                                                   156
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 146
# ANIMAL                                                                                 141
# RELATED TO BUS STOP                                                                    140
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            127
# DISREGARDING YIELD SIGN                                                                 87
# TEXTING                                                                                 72
# PASSING STOPPED SCHOOL BUS                                                              43
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               28
# OBSTRUCTED CROSSWALKS                                                                   23
# Name: SEC_CONTRIBUTORY_CAUSE, dtype: int64
# --------------------------------------
# STREET_DIRECTION
# --------------------------------------
# W    110875
# S     98077
# N     75859
# E     19908
# Name: STREET_DIRECTION, dtype: int64
# --------------------------------------
# PHOTOS_TAKEN_I
# --------------------------------------
# Y    2869
# N     669
# Name: PHOTOS_TAKEN_I, dtype: int64
# --------------------------------------
# STATEMENTS_TAKEN_I
# --------------------------------------
# Y    5587
# N     958
# Name: STATEMENTS_TAKEN_I, dtype: int64
# --------------------------------------
# DOORING_I
# --------------------------------------
# Y    246
# N    236
# Name: DOORING_I, dtype: int64
# --------------------------------------
# WORK_ZONE_I
# --------------------------------------
# Y    1705
# N     416
# Name: WORK_ZONE_I, dtype: int64
# --------------------------------------
# WORK_ZONE_TYPE
# --------------------------------------
# CONSTRUCTION    1183
# UNKNOWN          204
# MAINTENANCE      201
# UTILITY          117
# Name: WORK_ZONE_TYPE, dtype: int64
# --------------------------------------
# WORKERS_PRESENT_I
# --------------------------------------
# Y    438
# N     52
# Name: WORKERS_PRESENT_I, dtype: int64
# --------------------------------------
# NUM_UNITS
# --------------------------------------
# 2     269280
# 3      23262
# 1       6708
# 4       4252
# 5        831
# 6        240
# 7         70
# 8         51
# 9         16
# 10         6
# 11         2
# 16         1
# Name: NUM_UNITS, dtype: int64
# --------------------------------------
# MOST_SEVERE_INJURY
# --------------------------------------
# NO INDICATION OF INJURY     261519
# NONINCAPACITATING INJURY     23049
# REPORTED, NOT EVIDENT        15325
# INCAPACITATING INJURY         4684
# FATAL                          142
# Name: MOST_SEVERE_INJURY, dtype: int64
# --------------------------------------
# INJURIES_TOTAL
# --------------------------------------
# 0.0     261519
# 1.0      30277
# 2.0       8540
# 3.0       2695
# 4.0       1009
# 5.0        380
# 6.0        171
# 7.0         54
# 8.0         33
# 9.0         19
# 10.0         7
# 12.0         4
# 15.0         4
# 11.0         4
# 19.0         2
# 21.0         1
# Name: INJURIES_TOTAL, dtype: int64
# --------------------------------------
# INJURIES_FATAL
# --------------------------------------
# 0.0    304577
# 1.0       128
# 2.0        12
# 3.0         2
# Name: INJURIES_FATAL, dtype: int64
# --------------------------------------
# INJURIES_INCAPACITATING
# --------------------------------------
# 0.0    300005
# 1.0      3947
# 2.0       555
# 3.0       147
# 4.0        47
# 5.0        18
# Name: INJURIES_INCAPACITATING, dtype: int64
# --------------------------------------
# INJURIES_NON_INCAPACITATING
# --------------------------------------
# 0.0     280551
# 1.0      17824
# 2.0       4234
# 3.0       1330
# 4.0        489
# 5.0        166
# 6.0         61
# 7.0         25
# 8.0         22
# 9.0          7
# 10.0         6
# 18.0         2
# 11.0         1
# 21.0         1
# Name: INJURIES_NON_INCAPACITATING, dtype: int64
# --------------------------------------
# INJURIES_REPORTED_NOT_EVIDENT
# --------------------------------------
# 0.0     287318
# 1.0      13170
# 2.0       3028
# 3.0        784
# 4.0        242
# 5.0        124
# 6.0         23
# 7.0          8
# 9.0          6
# 8.0          5
# 11.0         4
# 15.0         4
# 10.0         3
# Name: INJURIES_REPORTED_NOT_EVIDENT, dtype: int64
# --------------------------------------
# INJURIES_NO_INDICATION
# --------------------------------------
# 2.0     176436
# 3.0      53518
# 1.0      33797
# 4.0      20969
# 5.0       8893
# 0.0       4152
# 6.0       3816
# 7.0       1662
# 8.0        744
# 9.0        337
# 10.0       133
# 11.0        63
# 12.0        43
# 14.0        40
# 13.0        22
# 16.0        12
# 17.0        11
# 15.0         9
# 21.0         9
# 20.0         8
# 37.0         5
# 42.0         4
# 27.0         4
# 26.0         4
# 18.0         3
# 28.0         3
# 40.0         3
# 19.0         3
# 25.0         2
# 29.0         2
# 61.0         2
# 34.0         2
# 30.0         2
# 22.0         1
# 38.0         1
# 46.0         1
# 31.0         1
# 24.0         1
# 36.0         1
# Name: INJURIES_NO_INDICATION, dtype: int64
# --------------------------------------
# INJURIES_UNKNOWN
# --------------------------------------
# 0.0    304719
# Name: INJURIES_UNKNOWN, dtype: int64
# --------------------------------------
# CRASH_HOUR
# --------------------------------------
# 16    24291
# 17    24285
# 15    24165
# 14    20948
# 8     19564
# 18    19271
# 13    19252
# 12    18852
# 11    17354
# 9     16037
# 7     15921
# 10    15520
# 19    13333
# 20     9712
# 21     8342
# 22     7504
# 6      7091
# 23     5897
# 0      4220
# 1      3246
# 5      3108
# 2      2745
# 3      2033
# 4      2028
# Name: CRASH_HOUR, dtype: int64
# --------------------------------------
# CRASH_DAY_OF_WEEK
# --------------------------------------
# 6    50869
# 5    45690
# 3    45059
# 4    45049
# 7    42901
# 2    42217
# 1    32934
# Name: CRASH_DAY_OF_WEEK, dtype: int64
# --------------------------------------
# CRASH_MONTH
# --------------------------------------
# 10    29288
# 9     27506
# 11    26999
# 12    26400
# 8     25418
# 3     25284
# 1     25209
# 7     24359
# 2     24294
# 6     23924
# 5     23906
# 4     22132
# Name: CRASH_MONTH, dtype: int64
# --------------------------------------
# SOME_DRIVER_ERROR
# --------------------------------------
# YES        220046
# UNKNOWN     64452
# NO          20221
# Name: SOME_DRIVER_ERROR, dtype: int64
# --------------------------------------
# SOME_DRIVER_SEC_ERROR
# --------------------------------------
# UNKNOWN    203322
# YES         89115
# NO          12282
# Name: SOME_DRIVER_SEC_ERROR, dtype: int64
# --------------------------------------
# GUILTY
# --------------------------------------
# 0    198810
# 1    105909
# Name: GUILTY, dtype: int64
# --------------------------------------
# SUN_GLARE
# --------------------------------------
# 0    245481
# 1     59238
# Name: SUN_GLARE, dtype: int64
# =================================================================================================
#                   Col_Name   Count
# 0                PERSON_ID  304719
# 2          CRASH_RECORD_ID  225979
# 3                  RD_NO_x  224866
# 4               VEHICLE_ID  304719
# 5             CRASH_DATE_x  184208
# 7                     CITY    4337
# 8                    STATE      52
# 9                  ZIPCODE    4415
# 11                     AGE      86
# 12   DRIVERS_LICENSE_STATE     110
# 18                HOSPITAL    1662
# 19              EMS_AGENCY    2780
# 31           CRASH_UNIT_ID  304719
# 32                 RD_NO_y  224866
# 33            CRASH_DATE_y  184208
# 38                    MAKE     414
# 39                   MODEL    1608
# 40         LIC_PLATE_STATE      52
# 41            VEHICLE_YEAR      67
# 51                TOWED_BY    4082
# 52                TOWED_TO    4224
# 68                  CMV_ID    1943
# 69                USDOT_NO     504
# 70                 CCMC_NO      99
# 71                 ILCC_NO      93
# 73                    GVWR     176
# 74            CARRIER_NAME    1271
# 76            CARRIER_CITY     366
# 93    TOTAL_VEHICLE_LENGTH      48
# 102                  RD_NO  224866
# 104             CRASH_DATE  184186
# 122   DATE_POLICE_NOTIFIED  200127
# 125              STREET_NO    9594
# 127            STREET_NAME    1341
# 128     BEAT_OF_OCCURRENCE     271
# 147               LATITUDE  108634
# 148              LONGITUDE  108631
# 149               LOCATION  108663
# 154            SUN_AZIMUTH  225875
# 155           SUN_ALTITUDE  225875

# %%
sample_df=selected_df.sample(100000, random_state=100)
#sample_df=selected_df.copy()

y = sample_df['GUILTY']
x = sample_df.drop(['GUILTY'],axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=100, test_size=0.25, stratify=y)

# %%
#numeric_columns = ['NUM_PASSENGERS']

nominal_columns = [ 'FIRST_CRASH_TYPE', 'FIRST_CONTACT_POINT', 
           'ROADWAY_SURFACE_COND','VEHICLE_DEFECT', 
           'MANEUVER',   'TRAFFIC_CONTROL_DEVICE']

# 'AIRBAG_DEPLOYED',  'PHYSICAL_CONDITION', 'AGE_GROUP', 'VEHICLE_AGE', 'DRIVERS_LICENSE_CLASS', 
#, 'TRAFFICWAY_TYPE', ,'SUN_GLARE' ,
#'ALIGNMENT' ,  'DEVICE_CONDITION','DRIVER_VISION', 

X_train = X_train[numeric_columns+nominal_columns]
X_test = X_test[numeric_columns+nominal_columns]

#X_train.info()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names=attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values
    

num_pipeline = Pipeline([
        ('selector', DataFrameSelector(numeric_columns)),
#        ('imputer', SimpleImputer(strategy = 'constant', fill_value=0))
 #       ('std_scaler', StandardScaler())
 #        ( 'polynomial', PolynomialFeatures(degree = 3, include_bias = False ))
        
    ])

cat_pipeline = Pipeline([
        ('selector', DataFrameSelector(nominal_columns)),
#        ('imputer', SimpleImputer(strategy = 'constant', fill_value='NA')),
        ('cat_encoder', OneHotEncoder(sparse=False, handle_unknown =  'ignore' )),
    ])


fu = FeatureUnion(transformer_list=[
#        ("num_pipeline", num_pipeline),
        ("cat_pipeline", cat_pipeline),
    ])

# %%
#X_train_transformed = fu.fit_transform(X_train[numeric_columns+nominal_columns])
#X_train.info(verbose=True, show_counts=True)

#columns=fu.transformer_list[1][1][2].get_feature_names_out()
#columns=np.insert(columns, 0, 'Intercept')
#transformed_df=pd.DataFrame(X_train_transformed, columns=X_train[numeric_columns+nominal_columns].columns)
#transformed_df=pd.DataFrame(X_train_transformed)

#transformed_df.info()
#transformed_df.info(verbose=True, show_counts=True)

# %%
XGB_pipeline = Pipeline([ ( 'fu', fu ),
                  ('boost', XGBClassifier(use_label_encoder=False, 
                                          eval_metric='auc', gamma= 0.02, max_depth=3, n_estimators=90, n_jobs=-1))
                 ])

# %%
pipe_grid={}
#pipe_grid={'boost__gamma':[0.01,0.015], 'boost__n_estimators':[110,130,150]}

gs_pipe = GridSearchCV(estimator=XGB_pipeline, param_grid=pipe_grid,  cv=2, scoring='roc_auc')

#pd.DataFrame(SCORERS.keys())

# %%
gs_pipe.fit(X_train, y_train)
#XGB_pipeline.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('fu',
#                                         FeatureUnion(transformer_list=[('cat_pipeline',
#                                                                         Pipeline(steps=[('selector',
#                                                                                          DataFrameSelector(attribute_names=['FIRST_CRASH_TYPE',
#                                                                                                                             'FIRST_CONTACT_POINT',
#                                                                                                                             'ROADWAY_SURFACE_COND',
#                                                                                                                             'VEHICLE_DEFECT',
#                                                                                                                             'MANEUVER',
#                                                                                                                             'TRAFFIC_CONTROL_DEVICE'])),
#                                                                                         ('cat_encoder',
#                                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                                        sparse=False))]))...
#                                                       max_delta_step=None,
#                                                       max_depth=3,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=90,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=None,
#                                                       reg_alpha=None,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=None,
#                                                       tree_method=None,
#                                                       use_label_encoder=False,
#                                                       validate_parameters=None,
#                                                       verbosity=None))]),
#              param_grid={}, scoring='roc_auc')

# %%
#                               interaction_constraints=None, learning_rate=None,
#                               max_delta_step=None, max_depth=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=100,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, random_state=None,
#                               reg_alpha=None, reg_lambda=None,
#                               scale_pos_weight=None, subsample=None,

# %%
y_pred_train=gs_pipe.predict(X_train)
y_pred_test=gs_pipe.predict(X_test)

#y_pred_train=XGB_pipeline.predict(X_train)
#y_pred_test=XGB_pipeline.predict(X_test)

# %%
gs_pipe.best_params_
# Out:
# {}

# %%
#print(XGB_pipeline.score(X_train, y_train ))
print(gs_pipe.score(X_train, y_train ))
print(classification_report(y_train, y_pred_train))
print('------------')
print(classification_report(y_test, y_pred_test))
# Out:
# 0.8523014720626841
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85     48863
#            1       0.73      0.63      0.68     26137
#
#     accuracy                           0.79     75000
#    macro avg       0.78      0.76      0.76     75000
# weighted avg       0.79      0.79      0.79     75000
#
# ------------
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84     16288
#            1       0.73      0.64      0.68      8712
#
#     accuracy                           0.79     25000
#    macro avg       0.77      0.75      0.76     25000
# weighted avg       0.79      0.79      0.79     25000

# %%
0.8773987570283558
              precision    recall  f1-score   support

           0       0.84      0.89      0.86      3951
           1       0.76      0.68      0.72      2049

    accuracy                           0.82      6000
   macro avg       0.80      0.78      0.79      6000
weighted avg       0.81      0.82      0.81      6000

------------
              precision    recall  f1-score   support

           0       0.82      0.88      0.85      1317
           1       0.73      0.62      0.67       683

    accuracy                           0.79      2000
   macro avg       0.78      0.75      0.76      2000
weighted avg       0.79      0.79      0.79      2000
# Out:
#   File "<tokenize>", line 4
#     0       0.84      0.89      0.86      3951
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def explore_cat_vars(df, n):
    col_counts=pd.DataFrame(df.nunique(),).reset_index()
    col_counts.columns=(["Col_Name", "Count"])
    for col in col_counts[col_counts['Count'] < n]['Col_Name']:
        print('--------------------------------------')
        print(col)
        print('--------------------------------------')
        print(df[col].value_counts())
    print("=================================================================================================")
    print(col_counts[col_counts['Count'] >= n])
