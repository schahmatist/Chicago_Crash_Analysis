# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta, timezone, date
from pysolar.solar import *
from zoneinfo import ZoneInfo
from dateutil import tz
#import datetime
#import zoneinfo

pd.set_option('display.max_columns', 80)
pd.set_option('display.max_rows', 200)

People_df=pd.read_csv("../data/raw/Traffic_Crashes_-_People.csv.gz", low_memory=False, compression='gzip')
Crashes_df=pd.read_csv("../data/raw/Traffic_Crashes_-_Crashes.csv.gz",low_memory=False, compression='gzip')
Vehicle_df=pd.read_csv("../data/raw/Traffic_Crashes_-_Vehicles.csv.gz",low_memory=False, compression='gzip')

# %%
Crashes=Crashes_df.copy()
People=People_df.copy()
Vehicle=Vehicle_df.copy()

# INITIAL FILTERING BEFORE the JOIN, FOR PERFORMANCE REASONS:

Crashes=Crashes[Crashes['REPORT_TYPE']=='ON SCENE']
#Crashes=Crashes.query('INJURIES_FATAL>0 or INJURIES_INCAPACITATING>0 or INJURIES_NON_INCAPACITATING>0')

Crashes=Crashes.query("CRASH_TYPE == 'INJURY AND / OR TOW DUE TO CRASH'")

#Vehicle = Vehicle[Vehicle_df['UNIT_NO']>1]
veh_type=['PASSENGER','SPORT UTILITY VEHICLE (SUV)','VAN/MINI-VAN','PICKUP','TRUCK - SINGLE UNIT','BUS OVER 15 PASS.']
Vehicle=Vehicle[Vehicle['VEHICLE_TYPE'].isin(veh_type)]

People=People[People['PERSON_TYPE']=="DRIVER"]


temp_df1=pd.merge(People, Vehicle, on=['CRASH_RECORD_ID','VEHICLE_ID'])
ALL_df=pd.merge(temp_df1, Crashes, on='CRASH_RECORD_ID')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198176 entries, 0 to 198175
# Columns: 148 entries, PERSON_ID to LOCATION
# dtypes: float64(23), int64(8), object(117)
# memory usage: 225.3+ MB
# NoneType

# %%
def explore_cat_vars(df, n):
    col_counts=pd.DataFrame(df.nunique(),).reset_index()
    col_counts.columns=(["Col_Name", "Count"])
    for col in col_counts[col_counts['Count'] < n]['Col_Name']:
        print('--------------------------------------')
        print(col)
        print('--------------------------------------')
        print(df[col].value_counts())
    print("=================================================================================================")
    print(col_counts[col_counts['Count'] >= n])

# %%
# GENERATING TARGET THROUGH binning and combining sec and prim causes:

targ_map ={ 'IMPROPER OVERTAKING/PASSING':'YES', 'UNABLE TO DETERMINE':'UNKNOWN',
       'IMPROPER BACKING':'YES', 'IMPROPER LANE USAGE':'YES',
       'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)':'YES',
       'DISREGARDING TRAFFIC SIGNALS':'YES',
       'FAILING TO REDUCE SPEED TO AVOID CRASH':'YES',
       'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER':'YES',
       'FAILING TO YIELD RIGHT-OF-WAY':'YES', 'EQUIPMENT - VEHICLE CONDITION':'NO',
       'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)':'NO',
       'IMPROPER TURNING/NO SIGNAL':'YES', 'FOLLOWING TOO CLOSELY':'YES',
       'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE':'YES', 'DISREGARDING STOP SIGN':'YES',
       'NOT APPLICABLE':'UNKNOWN', 'DISTRACTION - FROM INSIDE VEHICLE':'NO',
       'DISTRACTION - FROM OUTSIDE VEHICLE':'NO',
       'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)':'YES',
       'ROAD ENGINEERING/SURFACE/MARKING DEFECTS':'NO',
       'DISREGARDING OTHER TRAFFIC SIGNS':'YES', 'TEXTING':'YES',
       'DRIVING ON WRONG SIDE/WRONG WAY':'YES', 'PHYSICAL CONDITION OF DRIVER':'YES',
       'ANIMAL':'NO', 'WEATHER':'NO', 'ROAD CONSTRUCTION/MAINTENANCE':'NO',
       'DISREGARDING YIELD SIGN':'YES', 'CELL PHONE USE OTHER THAN TEXTING':'YES',
       'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST':'NO',
       'TURNING RIGHT ON RED':'YES', 'RELATED TO BUS STOP':'NO',
       'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)':'YES',
       'DISREGARDING ROAD MARKINGS':'YES', 'OBSTRUCTED CROSSWALKS':'NO',
       'PASSING STOPPED SCHOOL BUS':'YES',
       'EXCEEDING SAFE SPEED FOR CONDITIONS':'YES',
       'EXCEEDING AUTHORIZED SPEED LIMIT':'YES',
       'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT':'NO',
       'BICYCLE ADVANCING LEGALLY ON RED LIGHT':'NO'}

def create_target(this_driver_action, driver_error, driver_sec_error, phys_condition):
    if this_driver_action not in ['NONE','OTHER','UNKNOWN']:
        guilty='YES'
    elif this_driver_action == 'NONE':
        guilty='NO'
    elif this_driver_action in ['OTHER','UNKNOWN'] and phys_condition in ['MEDICATED','FATIGUED/ASLEEP','ILLNESS/FAINTED'] :
        guilty='NO'        
    else: 
        guilty = driver_error

    if guilty == 'UNKNOWN' and driver_error == 'UNKNOWN' and driver_sec_error == 'NO':
        guilty='NO'
    return guilty

ALL_df['SOME_DRIVER_ERROR']=ALL_df['PRIM_CONTRIBUTORY_CAUSE'].replace(targ_map)
ALL_df['SOME_DRIVER_SEC_ERROR']=ALL_df['SEC_CONTRIBUTORY_CAUSE'].replace(targ_map)

ALL_df['GUILTY']=ALL_df.apply(lambda row: create_target(row['DRIVER_ACTION'], row['SOME_DRIVER_ERROR'], 
                                                        row['SOME_DRIVER_SEC_ERROR'],row['PHYSICAL_CONDITION']), axis=1)

ALL_df = ALL_df[ALL_df['GUILTY']!='UNKNOWN']

# %%
ALL_df['GUILTY'].value_counts()
#Crashes.CRASH_TYPE.unique()
# Out:
# YES    88968
# NO     76258
# Name: GUILTY, dtype: int64

# %%
#temp_df=ALL_df[ALL_df['GUILTY']=='MAYBE'].copy()
#temp_df.head(80)[['CRASH_RECORD_ID','UNIT_NO','MODEL','GUILTY', 'DRIVER_ACTION','PRIM_CONTRIBUTORY_CAUSE','SEC_CONTRIBUTORY_CAUSE']].sort_values(by=['CRASH_RECORD_ID','UNIT_NO'])

# %%
# Dividing on training and testing sets

y=ALL_df['GUILTY']
ALL_COL=ALL_df.drop(['GUILTY'],axis=1)
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(ALL_COL, y, random_state=100, stratify=y)

train_df=pd.concat([X_train,Y_train], axis=1)
test_df=pd.concat([X_test,Y_test], axis=1)

# %%
df=train_df.copy()
#df.dropna(subset=['LONGITUDE','LATITUDE'], axis=0, inplace=True)

# to_zone = tz.gettz('America/Chicago')
# df["CRASH_DATE"]= df["CRASH_DATE"].map(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y %I:%M:%S %p").replace(tzinfo=to_zone))


# def get_sun_position (lat,long,date, direction, light, sun):
#     az=get_azimuth_fast(lat, long, date)
#     alt=get_altitude_fast(lat, long, date)
#     glare=0
#     if  alt < 40 and alt > 0 and light == 'DAYLIGHT' and sun == 'CLEAR':
#         if az <= 180 and direction in ('E','SE','S'):
#             glare=1
#         elif az >= 180 and direction in ('W','SW','S'):
#             glare=1
#         else: glare=0
#     return pd.Series([glare, az,alt])


# lambdafunc= lambda row: get_sun_position(row['LATITUDE'], 
#                              row['LONGITUDE'], 
#                              row['CRASH_DATE'].to_pydatetime(), 
#                              row['TRAVEL_DIRECTION'],
#                              row['LIGHTING_CONDITION'], 
#                              row['WEATHER_CONDITION'])
# #temp_df=df.head(20000).copy()

# df[['SUN_GLARE','SUN_AZIMUTH','SUN_ALTITUDE']]=df.apply(lambdafunc, axis=1)
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123919 entries, 90980 to 34054
# Data columns (total 151 columns):
#  #    Column                         Non-Null Count   Dtype
# ---   ------                         --------------   -----
#  0    PERSON_ID                      123919 non-null  object
#  1    PERSON_TYPE                    123919 non-null  object
#  2    CRASH_RECORD_ID                123919 non-null  object
#  3    RD_NO_x                        122926 non-null  object
#  4    VEHICLE_ID                     123919 non-null  float64
#  5    CRASH_DATE_x                   123919 non-null  object
#  6    SEAT_NO                        0 non-null       float64
#  7    CITY                           113093 non-null  object
#  8    STATE                          111484 non-null  object
#  9    ZIPCODE                        107763 non-null  object
#  10   SEX                            123919 non-null  object
#  11   AGE                            112480 non-null  float64
#  12   DRIVERS_LICENSE_STATE          109484 non-null  object
#  13   DRIVERS_LICENSE_CLASS          97815 non-null   object
#  14   SAFETY_EQUIPMENT               123919 non-null  object
#  15   AIRBAG_DEPLOYED                123919 non-null  object
#  16   EJECTION                       123919 non-null  object
#  17   INJURY_CLASSIFICATION          123919 non-null  object
#  18   HOSPITAL                       43867 non-null   object
#  19   EMS_AGENCY                     31707 non-null   object
#  20   EMS_RUN_NO                     0 non-null       object
#  21   DRIVER_ACTION                  123919 non-null  object
#  22   DRIVER_VISION                  123919 non-null  object
#  23   PHYSICAL_CONDITION             123919 non-null  object
#  24   PEDPEDAL_ACTION                0 non-null       object
#  25   PEDPEDAL_VISIBILITY            0 non-null       object
#  26   PEDPEDAL_LOCATION              0 non-null       object
#  27   BAC_RESULT                     123919 non-null  object
#  28   BAC_RESULT VALUE               835 non-null     float64
#  29   CELL_PHONE_USE                 277 non-null     object
#  30   CRASH_UNIT_ID                  123919 non-null  int64
#  31   RD_NO_y                        122926 non-null  object
#  32   CRASH_DATE_y                   123919 non-null  object
#  33   UNIT_NO                        123919 non-null  int64
#  34   UNIT_TYPE                      123919 non-null  object
#  35   NUM_PASSENGERS                 33310 non-null   float64
#  36   CMRC_VEH_I                     1625 non-null    object
#  37   MAKE                           123918 non-null  object
#  38   MODEL                          123900 non-null  object
#  39   LIC_PLATE_STATE                120635 non-null  object
#  40   VEHICLE_YEAR                   116332 non-null  float64
#  41   VEHICLE_DEFECT                 123919 non-null  object
#  42   VEHICLE_TYPE                   123919 non-null  object
#  43   VEHICLE_USE                    123919 non-null  object
#  44   TRAVEL_DIRECTION               123919 non-null  object
#  45   MANEUVER                       123919 non-null  object
#  46   TOWED_I                        69727 non-null   object
#  47   FIRE_I                         362 non-null     object
#  48   OCCUPANT_CNT                   123919 non-null  float64
#  49   EXCEED_SPEED_LIMIT_I           855 non-null     object
#  50   TOWED_BY                       53525 non-null   object
#  51   TOWED_TO                       32839 non-null   object
#  52   AREA_00_I                      3845 non-null    object
#  53   AREA_01_I                      62321 non-null   object
#  54   AREA_02_I                      36765 non-null   object
#  55   AREA_03_I                      15764 non-null   object
#  56   AREA_04_I                      14781 non-null   object
#  57   AREA_05_I                      18995 non-null   object
#  58   AREA_06_I                      17881 non-null   object
#  59   AREA_07_I                      17664 non-null   object
#  60   AREA_08_I                      28131 non-null   object
#  61   AREA_09_I                      9329 non-null    object
#  62   AREA_10_I                      18083 non-null   object
#  63   AREA_11_I                      38361 non-null   object
#  64   AREA_12_I                      39046 non-null   object
#  65   AREA_99_I                      4495 non-null    object
#  66   FIRST_CONTACT_POINT            123009 non-null  object
#  67   CMV_ID                         612 non-null     float64
#  68   USDOT_NO                       252 non-null     object
#  69   CCMC_NO                        42 non-null      object
#  70   ILCC_NO                        36 non-null      object
#  71   COMMERCIAL_SRC                 406 non-null     object
#  72   GVWR                           334 non-null     object
#  73   CARRIER_NAME                   581 non-null     object
#  74   CARRIER_STATE                  556 non-null     object
#  75   CARRIER_CITY                   541 non-null     object
#  76   HAZMAT_PLACARDS_I              10 non-null      object
#  77   HAZMAT_NAME                    2 non-null       object
#  78   UN_NO                          10 non-null      object
#  79   HAZMAT_PRESENT_I               452 non-null     object
#  80   HAZMAT_REPORT_I                442 non-null     object
#  81   HAZMAT_REPORT_NO               0 non-null       object
#  82   MCS_REPORT_I                   446 non-null     object
#  83   MCS_REPORT_NO                  1 non-null       object
#  84   HAZMAT_VIO_CAUSE_CRASH_I       444 non-null     object
#  85   MCS_VIO_CAUSE_CRASH_I          448 non-null     object
#  86   IDOT_PERMIT_NO                 18 non-null      object
#  87   WIDE_LOAD_I                    4 non-null       object
#  88   TRAILER1_WIDTH                 46 non-null      object
#  89   TRAILER2_WIDTH                 2 non-null       object
#  90   TRAILER1_LENGTH                25 non-null      float64
#  91   TRAILER2_LENGTH                1 non-null       float64
#  92   TOTAL_VEHICLE_LENGTH           100 non-null     float64
#  93   AXLE_CNT                       155 non-null     float64
#  94   VEHICLE_CONFIG                 485 non-null     object
#  95   CARGO_BODY_TYPE                492 non-null     object
#  96   LOAD_TYPE                      452 non-null     object
#  97   HAZMAT_OUT_OF_SERVICE_I        432 non-null     object
#  98   MCS_OUT_OF_SERVICE_I           446 non-null     object
#  99   HAZMAT_CLASS                   41 non-null      object
#  100  RD_NO                          122926 non-null  object
#  101  CRASH_DATE_EST_I               5856 non-null    object
#  102  CRASH_DATE                     123919 non-null  object
#  103  POSTED_SPEED_LIMIT             123919 non-null  int64
#  104  TRAFFIC_CONTROL_DEVICE         123919 non-null  object
#  105  DEVICE_CONDITION               123919 non-null  object
#  106  WEATHER_CONDITION              123919 non-null  object
#  107  LIGHTING_CONDITION             123919 non-null  object
#  108  FIRST_CRASH_TYPE               123919 non-null  object
#  109  TRAFFICWAY_TYPE                123919 non-null  object
#  110  LANE_CNT                       37650 non-null   float64
#  111  ALIGNMENT                      123919 non-null  object
#  112  ROADWAY_SURFACE_COND           123919 non-null  object
#  113  ROAD_DEFECT                    123919 non-null  object
#  114  REPORT_TYPE                    123919 non-null  object
#  115  CRASH_TYPE                     123919 non-null  object
#  116  INTERSECTION_RELATED_I         57838 non-null   object
#  117  NOT_RIGHT_OF_WAY_I             3386 non-null    object
#  118  HIT_AND_RUN_I                  21089 non-null   object
#  119  DAMAGE                         123919 non-null  object
#  120  DATE_POLICE_NOTIFIED           123919 non-null  object
#  121  PRIM_CONTRIBUTORY_CAUSE        123919 non-null  object
#  122  SEC_CONTRIBUTORY_CAUSE         123919 non-null  object
#  123  STREET_NO                      123919 non-null  int64
#  124  STREET_DIRECTION               123919 non-null  object
#  125  STREET_NAME                    123919 non-null  object
#  126  BEAT_OF_OCCURRENCE             123919 non-null  float64
#  127  PHOTOS_TAKEN_I                 1547 non-null    object
#  128  STATEMENTS_TAKEN_I             5733 non-null    object
#  129  DOORING_I                      363 non-null     object
#  130  WORK_ZONE_I                    895 non-null     object
#  131  WORK_ZONE_TYPE                 667 non-null     object
#  132  WORKERS_PRESENT_I              217 non-null     object
#  133  NUM_UNITS                      123919 non-null  int64
#  134  MOST_SEVERE_INJURY             123919 non-null  object
#  135  INJURIES_TOTAL                 123919 non-null  float64
#  136  INJURIES_FATAL                 123919 non-null  float64
#  137  INJURIES_INCAPACITATING        123919 non-null  float64
#  138  INJURIES_NON_INCAPACITATING    123919 non-null  float64
#  139  INJURIES_REPORTED_NOT_EVIDENT  123919 non-null  float64
#  140  INJURIES_NO_INDICATION         123919 non-null  float64
#  141  INJURIES_UNKNOWN               123919 non-null  float64
#  142  CRASH_HOUR                     123919 non-null  int64
#  143  CRASH_DAY_OF_WEEK              123919 non-null  int64
#  144  CRASH_MONTH                    123919 non-null  int64
#  145  LATITUDE                       123152 non-null  float64
#  146  LONGITUDE                      123152 non-null  float64
#  147  LOCATION                       123152 non-null  object
#  148  SOME_DRIVER_ERROR              123919 non-null  object
#  149  SOME_DRIVER_SEC_ERROR          123919 non-null  object
#  150  GUILTY                         123919 non-null  object
# dtypes: float64(23), int64(8), object(120)
# memory usage: 143.7+ MB

# %%
## REPLACE WITH SKLEARN IMPUTERS

df['AGE_GROUP'] = pd.cut(x=df['AGE'], bins=[15, 24, 35, 55, 70, 80, 100], 
                         labels=['YOUNG', 'YOUNG ADULTS','ADULTS','MIDDLE AGED','SENIORS', '80+'])

df=df[df['VEHICLE_YEAR']<=date.today().year]
df=df[df['VEHICLE_YEAR']>1900]

latest=date.today().year
oldest=df['VEHICLE_YEAR'].min()

vehicle_age=[oldest-1, latest-25, latest-15, latest-8, latest-3, latest ]
vehicle_age_labels=['25+ years old', '15-25 years old','8-15 years old','3-8 years old','0-3 years old']
df['VEHICLE_AGE'] = pd.cut(x=df['VEHICLE_YEAR'], bins=vehicle_age, labels=vehicle_age_labels, right=False)


df['EXCEED_SPEED_LIMIT_I']=df['EXCEED_SPEED_LIMIT_I'].fillna('UNKNOWN')
df['INTERSECTION_RELATED_I']=df['INTERSECTION_RELATED_I'].fillna('UNKNOWN')
df['FIRST_CONTACT_POINT']=df['FIRST_CONTACT_POINT'].fillna('UNKNOWN')
df['NUM_PASSENGERS']=df['NUM_PASSENGERS'].fillna(0)
df['DRIVERS_LICENSE_CLASS']=df['DRIVERS_LICENSE_CLASS'].fillna('D')

#df.dropna(subset=['AGE','MAKE','MODEL','VEHICLE_YEAR','LONGITUDE','LATITUDE'], axis=0, inplace=True)

df['VEHICLE_DEFECT']=df['VEHICLE_DEFECT'].replace( {'UNKNOWN':'NONE'}).copy()

#df=df[df['WEATHER_CONDITION']!='UNKNOWN']
#df=df[df['LIGHTING_CONDITION']!='UNKNOWN']

df=df[df['DRIVERS_LICENSE_CLASS'].isin(["A","B","C","D","DM","AM","BM","CD"])]

df['DRIVERS_LICENSE_CLASS']=np.where(df['DRIVERS_LICENSE_CLASS'].isin(["A","B","C","AM","BM","CD","S"]),'CDL',
                                     df['DRIVERS_LICENSE_CLASS'])
df['DRIVERS_LICENSE_CLASS']=np.where(df['DRIVERS_LICENSE_CLASS']=='DM','D', df['DRIVERS_LICENSE_CLASS'])

df.loc[df.query("CELL_PHONE_USE =='Y' and DRIVER_ACTION in (['UNKNOWN','NONE'])").index ,['DRIVER_ACTION']] = 'CELL PHONE USE'

df=df.query('SEX!="X"')

proper_speed=np.arange(0,80,5)
df=df[df['POSTED_SPEED_LIMIT'].isin(proper_speed)].copy()

# %%
cols=['GUILTY','DEVICE_CONDITION', 'FIRST_CRASH_TYPE', 'FIRST_CONTACT_POINT', 
           'TRAFFICWAY_TYPE','ROADWAY_SURFACE_COND','ROAD_DEFECT','POSTED_SPEED_LIMIT','VEHICLE_DEFECT',
            'ALIGNMENT', 'LIGHTING_CONDITION', 'WEATHER_CONDITION','SEX','AGE_GROUP','DRIVERS_LICENSE_CLASS',  
            'PHYSICAL_CONDITION', 'MANEUVER','NUM_PASSENGERS', 'VEHICLE_AGE', 'DRIVER_VISION']



X=df[cols].copy()

X=X.dropna()
X.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\DIMAFI~1\AppData\Local\Temp/ipykernel_14476/1501735083.py in <module>
#       6
#       7
# ----> 8 X=df[cols].copy()
#       9
#      10 X=X.dropna()
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['AGE_GROUP', 'VEHICLE_AGE'] not in index"

# %%
steps = [('imputer', SimpleImputer(strategy="most_frequent")), ('std_scaler', StandardScaler())]

# %%
from sklearn.pipeline import FeatureUnion
from sklearn.compose import ColumnTransformer

cat_encoded = ColumnTransformer(transformers=[
    ("ohe", OneHotEncoder(drop='first', handle_unknown="ignore"), ["category"])
], remainder="passthrough")

# %%
df
# Out:
#        PERSON_ID PERSON_TYPE  \
# 161234  O1064531      DRIVER
# 122206   O706156      DRIVER
# 67784    O358889      DRIVER
# 36930    O143439      DRIVER
# 115513   O661223      DRIVER
# ...          ...         ...
# 167597  O1158564      DRIVER
# 195103  O1236060      DRIVER
# 23318    O935286      DRIVER
# 69940    O372091      DRIVER
# 152526  O1031710      DRIVER
#
#                                           CRASH_RECORD_ID   RD_NO_x  \
# 161234  bbe190f76f29a7d1fac1c31b34c1c35f22d8db74a2f8f8...  JE179358
# 122206  282c4d7a7cfa5b7beebbdc253780b0e71e7c48b7bc6210...  JC372076
# 67784   10b423d1e2b4f6b0bc627463bcf5f9afa85f87ec38c324...  JB215002
# 36930   e7bc08a46c43b0aa0623df8dd07096f6f825851f503d14...  JA214262
# 115513  381533e05f81f31fc63054d58f984be20c2a9e87a6d09e...  JC289763
# ...                                                   ...       ...
# 167597  fb74fd80835ccc360bd50f7464eb47c5964a1a9f5beca6...  JE332147
# 195103  e687b9544244ec8e9137239a878715bd0e3aca2d559acd...  JE459923
# 23318   ee3ede1f523a7b41c43736661460b7d9c01a0ff8ddea95...  JD326729
# 69940   2712002f5dbf976599258ee4f13a29617bc0d06eba2ed1...  JB238456
# 152526  84a1bff430af1446406d0ccae0de4cf9e30d3a77260aba...  JE125754
#
#         VEHICLE_ID            CRASH_DATE_x  SEAT_NO          CITY STATE  \
# 161234   1009528.0  03/25/2021 01:25:00 PM      NaN       CHICAGO    IL
# 122206    671598.0  07/31/2019 06:25:00 AM      NaN       CHICAGO    IL
# 67784     346135.0  04/07/2018 02:37:00 PM      NaN       CHICAGO    IL
# 36930     142978.0  04/06/2017 01:15:00 AM      NaN       LANSING    IL
# 115513    629544.0  06/03/2019 04:40:00 AM      NaN       CHICAGO    IL
# ...            ...                     ...      ...           ...   ...
# 167597   1099019.0  08/09/2021 09:35:00 PM      NaN  CEDAR RAPIDS    IA
# 195103   1173118.0  11/29/2021 12:00:00 AM      NaN       CHICAGO    IL
# 23318     886654.0  08/10/2020 01:25:00 AM      NaN       CHICAGO    IL
# 69940     358629.0  04/26/2018 08:42:00 AM      NaN       CHICAGO    IL
# 152526    977885.0  01/28/2021 02:34:00 PM      NaN       CHICAGO    IL
#
#        ZIPCODE SEX   AGE DRIVERS_LICENSE_STATE DRIVERS_LICENSE_CLASS  \
# 161234     NaN   M  22.0                    IL                     D
# 122206   60615   M  26.0                    IL                     D
# 67784    60622   M  53.0                    IL                     D
# 36930    60438   F  36.0                    IL                     D
# 115513   60625   M  38.0                    IL                     D
# ...        ...  ..   ...                   ...                   ...
# 167597   52404   F  28.0                    IA                     D
# 195103   60623   F  55.0                    IL                     D
# 23318    60613   M  27.0                    IL                     D
# 69940    60612   F  22.0                   NaN                     D
# 152526   60634   M  16.0                    IL                     D
#
#         SAFETY_EQUIPMENT        AIRBAG_DEPLOYED EJECTION  \
# 161234  SAFETY BELT USED         DEPLOYED, SIDE     NONE
# 122206  SAFETY BELT USED         DID NOT DEPLOY     NONE
# 67784   SAFETY BELT USED         DID NOT DEPLOY     NONE
# 36930   SAFETY BELT USED         DID NOT DEPLOY     NONE
# 115513     USAGE UNKNOWN        DEPLOYED, FRONT     NONE
# ...                  ...                    ...      ...
# 167597     USAGE UNKNOWN  DEPLOYED, COMBINATION     NONE
# 195103  SAFETY BELT USED         NOT APPLICABLE     NONE
# 23318   SAFETY BELT USED        DEPLOYED, FRONT     NONE
# 69940   SAFETY BELT USED         DID NOT DEPLOY     NONE
# 152526  SAFETY BELT USED         DID NOT DEPLOY     NONE
#
#            INJURY_CLASSIFICATION    HOSPITAL EMS_AGENCY EMS_RUN_NO  \
# 161234     REPORTED, NOT EVIDENT         NaN    CFD A78        NaN
# 122206   NO INDICATION OF INJURY         NaN        NaN        NaN
# 67784    NO INDICATION OF INJURY         NaN      AMB 4        NaN
# 36930    NO INDICATION OF INJURY         DNA        DNA        NaN
# 115513   NO INDICATION OF INJURY         NaN        NaN        NaN
# ...                          ...         ...        ...        ...
# 167597   NO INDICATION OF INJURY  ST BERNARD         55        NaN
# 195103   NO INDICATION OF INJURY         NaN        NaN        NaN
# 23318   NONINCAPACITATING INJURY    MT SINAI        CFD        NaN
# 69940    NO INDICATION OF INJURY         NaN        NaN        NaN
# 152526   NO INDICATION OF INJURY         NaN        NaN        NaN
#
#                DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION  \
# 161234                  NONE  NOT OBSCURED             NORMAL             NaN
# 122206  IMPROPER LANE CHANGE  NOT OBSCURED             NORMAL             NaN
# 67784                   NONE  NOT OBSCURED             NORMAL             NaN
# 36930                   NONE  NOT OBSCURED             NORMAL             NaN
# 115513         IMPROPER TURN       UNKNOWN             NORMAL             NaN
# ...                      ...           ...                ...             ...
# 167597                  NONE  NOT OBSCURED             NORMAL             NaN
# 195103      IMPROPER BACKING  NOT OBSCURED             NORMAL             NaN
# 23318                  OTHER  NOT OBSCURED             NORMAL             NaN
# 69940       IMPROPER PASSING  NOT OBSCURED             NORMAL             NaN
# 152526                  NONE       UNKNOWN             NORMAL             NaN
#
#        PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT  \
# 161234                 NaN               NaN  TEST NOT OFFERED
# 122206                 NaN               NaN  TEST NOT OFFERED
# 67784                  NaN               NaN  TEST NOT OFFERED
# 36930                  NaN               NaN  TEST NOT OFFERED
# 115513                 NaN               NaN  TEST NOT OFFERED
# ...                    ...               ...               ...
# 167597                 NaN               NaN  TEST NOT OFFERED
# 195103                 NaN               NaN  TEST NOT OFFERED
# 23318                  NaN               NaN  TEST NOT OFFERED
# 69940                  NaN               NaN  TEST NOT OFFERED
# 152526                 NaN               NaN  TEST NOT OFFERED
#
#         BAC_RESULT VALUE CELL_PHONE_USE  CRASH_UNIT_ID   RD_NO_y  \
# 161234               NaN            NaN        1064531  JE179358
# 122206               NaN            NaN         706156  JC372076
# 67784                NaN            NaN         358889  JB215002
# 36930                NaN            NaN         143439  JA214262
# 115513               NaN            NaN         661223  JC289763
# ...                  ...            ...            ...       ...
# 167597               NaN            NaN        1158564  JE332147
# 195103               NaN            NaN        1236060  JE459923
# 23318                NaN            NaN         935286  JD326729
# 69940                NaN            NaN         372091  JB238456
# 152526               NaN            NaN        1031710  JE125754
#
#                   CRASH_DATE_y  UNIT_NO UNIT_TYPE  NUM_PASSENGERS CMRC_VEH_I  \
# 161234  03/25/2021 01:25:00 PM        2    DRIVER             0.0        NaN
# 122206  07/31/2019 06:25:00 AM        1    DRIVER             0.0        NaN
# 67784   04/07/2018 02:37:00 PM        2    DRIVER             0.0        NaN
# 36930   04/06/2017 01:15:00 AM        2    DRIVER             0.0        NaN
# 115513  06/03/2019 04:40:00 AM        1    DRIVER             1.0        NaN
# ...                        ...      ...       ...             ...        ...
# 167597  08/09/2021 09:35:00 PM        2    DRIVER             4.0        NaN
# 195103  11/29/2021 12:00:00 AM        1    DRIVER             0.0        NaN
# 23318   08/10/2020 01:25:00 AM        1    DRIVER             0.0        NaN
# 69940   04/26/2018 08:42:00 AM        2    DRIVER             3.0        NaN
# 152526  01/28/2021 02:34:00 PM        2    DRIVER             1.0        NaN
#
#                                     MAKE  \
# 161234                         CHEVROLET
# 122206                             HONDA
# 67784         TOYOTA MOTOR COMPANY, LTD.
# 36930                               JEEP
# 115513                            SUBARU
# ...                                  ...
# 167597                            TOYOTA
# 195103                         CHEVROLET
# 23318   GENERAL MOTORS CORPORATION (GMC)
# 69940                            PONTIAC
# 152526                            TOYOTA
#
#                                                     MODEL LIC_PLATE_STATE  \
# 161234                                             IMPALA              IL
# 122206                                              CIVIC              VA
# 67784                                             Avensis              IL
# 36930   Grand Cherokee (for vehicle years 1989 to pres...              IL
# 115513                                            OUTBACK              IL
# ...                                                   ...             ...
# 167597                                              CAMRY              IA
# 195103                                              ASTRO              IL
# 23318                                             TERRAIN              IL
# 69940                                            GRAND AM              IL
# 152526                                               RAV4              IL
#
#         ...  INTERSECTION_RELATED_I NOT_RIGHT_OF_WAY_I HIT_AND_RUN_I  \
# 161234  ...                       Y                NaN           NaN
# 122206  ...                 UNKNOWN                NaN           NaN
# 67784   ...                       Y                NaN           NaN
# 36930   ...                       Y                NaN           NaN
# 115513  ...                       Y                NaN           NaN
# ...     ...                     ...                ...           ...
# 167597  ...                 UNKNOWN                NaN             N
# 195103  ...                 UNKNOWN                NaN           NaN
# 23318   ...                 UNKNOWN                NaN           NaN
# 69940   ...                 UNKNOWN                  Y           NaN
# 152526  ...                 UNKNOWN                NaN             Y
#
#                DAMAGE    DATE_POLICE_NOTIFIED  \
# 161234    OVER $1,500  03/25/2021 01:28:00 PM
# 122206    OVER $1,500  07/31/2019 06:32:00 AM
# 67784     OVER $1,500  04/07/2018 02:38:00 PM
# 36930     OVER $1,500  04/06/2017 01:20:00 AM
# 115513  $501 - $1,500  06/03/2019 04:50:00 AM
# ...               ...                     ...
# 167597    OVER $1,500  08/09/2021 09:36:00 PM
# 195103   $500 OR LESS  11/29/2021 07:46:00 AM
# 23318     OVER $1,500  08/10/2020 01:30:00 AM
# 69940     OVER $1,500  04/26/2018 08:51:00 AM
# 152526    OVER $1,500  01/28/2021 03:26:00 PM
#
#                                   PRIM_CONTRIBUTORY_CAUSE  \
# 161234                                UNABLE TO DETERMINE
# 122206  EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST
# 67784                        DISREGARDING TRAFFIC SIGNALS
# 36930                        DISREGARDING TRAFFIC SIGNALS
# 115513                         IMPROPER TURNING/NO SIGNAL
# ...                                                   ...
# 167597                                UNABLE TO DETERMINE
# 195103                DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# 23318                   DISTRACTION - FROM INSIDE VEHICLE
# 69940                         IMPROPER OVERTAKING/PASSING
# 152526                                UNABLE TO DETERMINE
#
#                                    SEC_CONTRIBUTORY_CAUSE STREET_NO  \
# 161234                                UNABLE TO DETERMINE      5100
# 122206                                UNABLE TO DETERMINE      5099
# 67784                                      NOT APPLICABLE         1
# 36930                                             WEATHER     11400
# 115513                                     NOT APPLICABLE        64
# ...                                                   ...       ...
# 167597                                     NOT APPLICABLE      6445
# 195103                                UNABLE TO DETERMINE      1351
# 23318   DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGAT...      1346
# 69940                                      NOT APPLICABLE       155
# 152526                                     NOT APPLICABLE      5615
#
#         STREET_DIRECTION                  STREET_NAME BEAT_OF_OCCURRENCE  \
# 161234                 S                   KEELER AVE              815.0
# 122206                 S             LAKE SHORE DR NB              222.0
# 67784                  E                      31ST ST              211.0
# 36930                  S              ST LAWRENCE AVE              531.0
# 115513                 W              LOWER WACKER DR              111.0
# ...                  ...                          ...                ...
# 167597                 S  DR MARTIN LUTHER KING JR DR              312.0
# 195103                 S                 LAWNDALE AVE             1011.0
# 23318                  S                  WESTERN AVE             1023.0
# 69940                  S                   PULASKI RD             1122.0
# 152526                 W                   ADDISON ST             1633.0
#
#        PHOTOS_TAKEN_I STATEMENTS_TAKEN_I DOORING_I WORK_ZONE_I WORK_ZONE_TYPE  \
# 161234            NaN                NaN       NaN         NaN            NaN
# 122206            NaN                NaN       NaN         NaN            NaN
# 67784             NaN                NaN       NaN         NaN            NaN
# 36930             NaN                NaN       NaN         NaN            NaN
# 115513            NaN                NaN       NaN         NaN            NaN
# ...               ...                ...       ...         ...            ...
# 167597            NaN                NaN       NaN         NaN            NaN
# 195103            NaN                NaN       NaN         NaN            NaN
# 23318             NaN                NaN       NaN         NaN            NaN
# 69940             NaN                  Y       NaN         NaN            NaN
# 152526            NaN                NaN       NaN         NaN            NaN
#
#        WORKERS_PRESENT_I NUM_UNITS        MOST_SEVERE_INJURY INJURIES_TOTAL  \
# 161234               NaN         2     REPORTED, NOT EVIDENT            1.0
# 122206               NaN         1   NO INDICATION OF INJURY            0.0
# 67784                NaN         2  NONINCAPACITATING INJURY            1.0
# 36930                NaN         2   NO INDICATION OF INJURY            0.0
# 115513               NaN         2  NONINCAPACITATING INJURY            1.0
# ...                  ...       ...                       ...            ...
# 167597               NaN         5     REPORTED, NOT EVIDENT            1.0
# 195103               NaN         2   NO INDICATION OF INJURY            0.0
# 23318                NaN         1  NONINCAPACITATING INJURY            1.0
# 69940                NaN         4  NONINCAPACITATING INJURY            2.0
# 152526               NaN         2   NO INDICATION OF INJURY            0.0
#
#        INJURIES_FATAL INJURIES_INCAPACITATING INJURIES_NON_INCAPACITATING  \
# 161234            0.0                     0.0                         0.0
# 122206            0.0                     0.0                         0.0
# 67784             0.0                     0.0                         1.0
# 36930             0.0                     0.0                         0.0
# 115513            0.0                     0.0                         1.0
# ...               ...                     ...                         ...
# 167597            0.0                     0.0                         0.0
# 195103            0.0                     0.0                         0.0
# 23318             0.0                     0.0                         1.0
# 69940             0.0                     0.0                         2.0
# 152526            0.0                     0.0                         0.0
#
#        INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 161234                           1.0                    1.0              0.0
# 122206                           0.0                    1.0              0.0
# 67784                            0.0                    1.0              0.0
# 36930                            0.0                    2.0              0.0
# 115513                           0.0                    2.0              0.0
# ...                              ...                    ...              ...
# 167597                           1.0                    9.0              0.0
# 195103                           0.0                    1.0              0.0
# 23318                            0.0                    0.0              0.0
# 69940                            0.0                    4.0              0.0
# 152526                           0.0                    3.0              0.0
#
#        CRASH_HOUR  CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 161234         13                  5           3  41.800399 -87.728415
# 122206          6                  4           7  41.802669 -87.581284
# 67784          14                  7           4  41.838193 -87.626554
# 36930           1                  5           4  41.687263 -87.608448
# 115513          4                  2           6  41.887069 -87.630368
# ...           ...                ...         ...        ...        ...
# 167597         21                  2           8  41.777092 -87.615401
# 195103          0                  2          11  41.862907 -87.717615
# 23318           1                  2           8  41.863402 -87.686096
# 69940           8                  5           4  41.878094 -87.725435
# 152526         14                  5           1  41.945759 -87.767404
#
#                                         LOCATION SOME_DRIVER_ERROR  \
# 161234  POINT (-87.728414859614 41.800398930524)           UNKNOWN
# 122206  POINT (-87.581283737295 41.802669236803)                NO
# 67784   POINT (-87.626554049986 41.838193469891)               YES
# 36930   POINT (-87.608448361052 41.687262736694)               YES
# 115513  POINT (-87.630367868642 41.887069304408)               YES
# ...                                          ...               ...
# 167597  POINT (-87.615401190089 41.777091830406)           UNKNOWN
# 195103   POINT (-87.71761487249 41.862907384201)               YES
# 23318   POINT (-87.686096255788 41.863402446998)                NO
# 69940   POINT (-87.725435110682 41.878093550787)               YES
# 152526  POINT (-87.767404416774 41.945759247388)           UNKNOWN
#
#        SOME_DRIVER_SEC_ERROR GUILTY SUN_GLARE         SUN_AZIMUTH  \
# 161234               UNKNOWN     NO         0  190.50139808315518
# 122206               UNKNOWN    YES         0   71.28256620290195
# 67784                UNKNOWN     NO         0  220.34217323677666
# 36930                     NO     NO         0   7.306256723969229
# 115513               UNKNOWN    YES         0   52.05193423567401
# ...                      ...    ...       ...                 ...
# 167597               UNKNOWN     NO         0   309.4800992628039
# 195103               UNKNOWN    YES         0  13.210142651258698
# 23318                    YES     NO         0   8.443375131472795
# 69940                UNKNOWN    YES         0    99.0881101336339
# 152526               UNKNOWN     NO         0  217.97282034585373
#
#        SUN_ALTITUDE     AGE_GROUP      VEHICLE_AGE
# 161234    48.940096         YOUNG   8-15 years old
# 122206     6.384650  YOUNG ADULTS  15-25 years old
# 67784     47.693183        ADULTS   8-15 years old
# 36930    -42.065313        ADULTS   8-15 years old
# 115513    -6.482957        ADULTS    3-8 years old
# ...             ...           ...              ...
# 167597   -16.534346  YOUNG ADULTS   8-15 years old
# 195103   -69.537987   MIDDLE AGED  15-25 years old
# 23318    -32.676904  YOUNG ADULTS   8-15 years old
# 69940     29.814971         YOUNG  15-25 years old
# 152526    20.293814         YOUNG  15-25 years old
#
# [98600 rows x 156 columns]
